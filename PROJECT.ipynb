# %%
#gerekli kütüphanelerin çağırılması
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline 
import warnings
warnings.filterwarnings("ignore")

# %%
#veri setinin yüklenmesi
dataset=pd.read_csv("data\cc_general.csv")
#dataset=dataset.fillna(0)
dataset.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           8950 non-null   object
#  1   BALANCE                           8950 non-null   float64
#  2   BALANCE_FREQUENCY                 8950 non-null   float64
#  3   PURCHASES                         8950 non-null   float64
#  4   ONEOFF_PURCHASES                  8950 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  6   CASH_ADVANCE                      8950 non-null   float64
#  7   PURCHASES_FREQUENCY               8950 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8950 non-null   float64
# ...

# %%
#CREDIT_LIMIT ve MINIMUM_PAYMENT sütünlarındaki eksik verilerin doldurulması veya sütünların drop kullanılarak silinmesi 

#sütundaki eksik verilerin mevcut verilerin mean'i ile doldurulması
dataset['CREDIT_LIMIT'].fillna((dataset['CREDIT_LIMIT'].mean()), inplace=True)
dataset['MINIMUM_PAYMENTS'].fillna((dataset['MINIMUM_PAYMENTS'].mean()), inplace=True)

#dataset.drop(["CREDIT_LIMIT", "MINIMUM_PAYMENTS"], axis=1, inplace=True) #sütunların silinmesi

# %%
#veri setinin ilk 5 satırının görselleştirlmesi
dataset.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# ...

# %%
dataset.shape
# Out:
# (8950, 18)

# %%
#CUST_ID sütunundaki bilgilere ihtiyaç duyulmadığı için elimine edilmesi
dataset.drop(["CUST_ID"], axis=1, inplace=True)
dataset.head()
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    40.900749           0.818182      95.40              0.00
# 1  3202.467416           0.909091       0.00              0.00
# 2  2495.148862           1.000000     773.17            773.17
# 3  1666.670542           0.636364    1499.00           1499.00
# 4   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# ...

# %%
#Korelasyon
correlations=dataset.corr()
correlations
# Out:
#                                    BALANCE  BALANCE_FREQUENCY  PURCHASES  \
# BALANCE                           1.000000           0.322412   0.181261
# BALANCE_FREQUENCY                 0.322412           1.000000   0.133674
# PURCHASES                         0.181261           0.133674   1.000000
# ONEOFF_PURCHASES                  0.164350           0.104323   0.916845
# INSTALLMENTS_PURCHASES            0.126469           0.124292   0.679896
# CASH_ADVANCE                      0.496692           0.099388  -0.051474
# PURCHASES_FREQUENCY              -0.077944           0.229715   0.393017
# ONEOFF_PURCHASES_FREQUENCY        0.073166           0.202415   0.498430
# PURCHASES_INSTALLMENTS_FREQUENCY -0.063186           0.176079   0.315567
# CASH_ADVANCE_FREQUENCY            0.449218           0.191873  -0.120143
# CASH_ADVANCE_TRX                  0.385152           0.141555  -0.067175
# PURCHASES_TRX                     0.154338           0.189626   0.689561
# ...

# %%
#korelasyonun heatmap ile göreselleştirlmesi
f, ax=plt.subplots(figsize=(20,20))
sns.heatmap(correlations, annot=True)

# %%
#verilerin ölçeklendirilmesi
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X=sc.fit_transform(dataset)
X
# Out:
# array([[-0.73198937, -0.24943448, -0.42489974, ..., -0.31096755,
#         -0.52555097,  0.36067954],
#        [ 0.78696085,  0.13432467, -0.46955188, ...,  0.08931021,
#          0.2342269 ,  0.36067954],
#        [ 0.44713513,  0.51808382, -0.10766823, ..., -0.10166318,
#         -0.52555097,  0.36067954],
#        ...,
#        [-0.7403981 , -0.18547673, -0.40196519, ..., -0.33546549,
#          0.32919999, -4.12276757],
#        [-0.74517423, -0.18547673, -0.46955188, ..., -0.34690648,
#          0.32919999, -4.12276757],
#        [-0.57257511, -0.88903307,  0.04214581, ..., -0.33294642,
#         -0.52555097, -4.12276757]])

# %%
#Elbow Method (dirsek metodu)
from sklearn.cluster import KMeans

score=[]

for i in range(1,20):
    model=KMeans(n_clusters=i)
    model.fit(X)
    score.append(model.inertia_)

plt.plot(score, "m*-")
plt.xlabel("Cluster")
plt.ylabel("Score")
plt.show()

# %%
#K-MEANS

kmeans=KMeans(8)
kmeans.fit(X)
y_kmeans=kmeans.fit_predict(X)
labels=kmeans.labels_

# %%
kmeans.cluster_centers_.shape
# Out:
# (8, 17)

# %%
centers=pd.DataFrame(data=kmeans.cluster_centers_,columns=[dataset.columns])
centers
# Out:
#     BALANCE BALANCE_FREQUENCY  PURCHASES ONEOFF_PURCHASES  \
# 0 -0.701236         -2.142837  -0.311152        -0.235718
# 1  0.018717          0.403675  -0.362096        -0.247410
# 2 -0.336050         -0.347078  -0.289267        -0.215966
# 3  0.901817          0.466986   2.270963         1.756936
# 4 -0.162252          0.391726   0.453951         0.593849
# 5 -0.364734          0.333522  -0.037450        -0.244422
# 6  1.923051          0.337717  11.212042        10.600367
# 7  1.699636          0.393399  -0.216668        -0.155678
#
#   INSTALLMENTS_PURCHASES CASH_ADVANCE PURCHASES_FREQUENCY  \
# 0              -0.302542    -0.322027           -0.556270
# 1              -0.401524    -0.085698           -0.867394
# 2              -0.286835     0.068284           -0.203078
# 3               2.141920    -0.195512            1.158629
# 4              -0.017799    -0.332768            0.941678
# 5               0.360306    -0.364596            0.990943
# ...

# %%
cluster=pd.concat([dataset, pd.DataFrame({"cluster":labels})], axis=1)
cluster.head()
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    40.900749           0.818182      95.40              0.00
# 1  3202.467416           0.909091       0.00              0.00
# 2  2495.148862           1.000000     773.17            773.17
# 3  1666.670542           0.636364    1499.00           1499.00
# 4   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# ...

# %%
#Temel Bileşenler Analizi (Principal Component Analysis - PCA)
from sklearn.decomposition import PCA

#özellik boyutunun küçültülmesi
pca=PCA(n_components=2)
principal_component=pca.fit_transform(X)
principal_component
# Out:
# array([[-1.68221988, -1.07645642],
#        [-1.13829423,  2.5064759 ],
#        [ 0.96968504, -0.38349442],
#        ...,
#        [-0.92620318, -1.81078597],
#        [-2.33655238, -0.65798407],
#        [-0.55642347, -0.40046007]])

# %%
#PCA Data Frame'inin oluşturulması
pca_df=pd.DataFrame(data=principal_component, columns=["pca1", "pca2"])
pca_df.head()
# Out:
#        pca1      pca2
# 0 -1.682220 -1.076456
# 1 -1.138294  2.506476
# 2  0.969685 -0.383494
# 3 -0.873627  0.043158
# 4 -1.599433 -0.688585

# %%
#concat kullanarak cluster label'ları ve oluşturulan datafarame'i birleştirme
pca_df=pd.concat([pca_df, pd.DataFrame({"cluster":labels})], axis=1)
pca_df.head()
# Out:
#        pca1      pca2  cluster
# 0 -1.682220 -1.076456        1
# 1 -1.138294  2.506476        7
# 2  0.969685 -0.383494        4
# 3 -0.873627  0.043158        1
# 4 -1.599433 -0.688585        1

# %%
#scatterplot kullanarak görselleştirmenin yapılması
plt.figure(figsize=(8,8))
model=sns.scatterplot(x="pca1", y="pca2", hue="cluster",
                   data=pca_df, 
                   palette=["rebeccapurple","olive", "darkorange","pink","maroon","y", "indianred", "darkseagreen"])
plt.show()
